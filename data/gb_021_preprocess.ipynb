# %% [markdown]
# # 환경 설정
# - 필요한 라이브러리 로드 (pandas, numpy, os, re)
# - 구글 드라이브 연동 (구글 코랩에서 데이터 파일에 접근하기 위함)

# %%
import pandas as pd
import numpy as np
import os
import sys
import re

# %% [markdown]
# # 데이터 불러오기

# %%
# 데이터 불러오기

df = pd.read_excel('result/ron10_data.xlsx')
print(df.shape)

df
# Out:
# (10, 9)
#    r_id          r_id_raw                              title writer  \
# 0     1  ma_013_0010_0020                                創刊辭    NaN
# 1     2  ma_013_0010_0030                             世界를 알라    NaN
# 2     3  ma_013_0010_0060                   時急히 解決할 朝鮮의 二大問題    朴達成
# 3     4  ma_013_0020_0020        世界 三大 問題의 波及과 朝鮮人의 覺悟如何, 社說    NaN
# 4     5  ma_013_0020_0040                      最近 朝鮮社會運動의 二三    李敦化
# 5     6  ma_013_0020_0050  急激히 向上되는 朝鮮靑年의 思想界, 可賀할 朝鮮靑年의 知識熱    朴達成
# 6     7  ma_013_0030_0020                     吾人의 新紀元을 宣言하노라    NaN
# 7     8  ma_013_0030_0030                           新時代와 新人物    NaN
# 8     9  ma_013_0030_0050                          家族制度의 側面觀   滄海居士
# 9    10  ma_013_0030_0070                         朝鮮女子의 今後行路   妙香山人
#
#   gisa_class        date                                          url  year  \
# 0    사고·편집후기  1920-06-25  http://db.history.go.kr/id/ma_013_0010_0020  1920
# 1         논설  1920-06-25  http://db.history.go.kr/id/ma_013_0010_0030  1920
# 2         논설  1920-06-25  http://db.history.go.kr/id/ma_013_0010_0060  1920
# 3         논설  1920-07-25  http://db.history.go.kr/id/ma_013_0020_0020  1920
# 4         논설  1920-07-25  http://db.history.go.kr/id/ma_013_0020_0040  1920
# 5         논설  1920-07-25  http://db.history.go.kr/id/ma_013_0020_0050  1920
# 6         논설  1920-08-25  http://db.history.go.kr/id/ma_013_0030_0020  1920
# 7         논설  1920-08-25  http://db.history.go.kr/id/ma_013_0030_0030  1920
# 8         논설  1920-08-25  http://db.history.go.kr/id/ma_013_0030_0050  1920
# 9         논설  1920-08-25  http://db.history.go.kr/id/ma_013_0030_0070  1920
#
#                                              content
# 0  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1  世界를 알라\n一\n사람은 天使도 안이며 野獸도 안이오 오즉 사람일 뿐이로다. 이만...
# 2  時急히 解決할 朝鮮의 二大問題\n朴達成\n남은 汽車를 타고 千里에 달아나는데 우리는...
# 3  世界 三大 問題의 波及과 朝鮮人의 覺悟如何, 社說\n1. 三大 問題는 그를 吸收하고...
# 4  最近 朝鮮社會運動의 二三\n李敦化\n朝鮮敎育會, 朝鮮學生大會, 朝鮮勞働共濟會의 趣旨...
# 5  急激히 向上되는 朝鮮靑年의 思想界, 可賀할 朝鮮靑年의 知識熱\n朴達成\n無私한 태양...
# 6  吾人의 新紀元을 宣言하노라\n吾人은 均히 自國 歷史의 長遠을 자랑하고 自家譜乘의 久...
# 7  新時代와 新人物\n一. 改造라 함은 人類의 靈力이 自然의 上에 作用함을 이름이라\n...
# 8  家族制度의 側面觀\n滄海居士\n一. 家族制度의 變遷\n家族制度에도 美點이 업는 바 ...
# 9  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...

# %%
df1 = df[['r_id', 'title', 'content']]
df1
# Out:
#    r_id                              title  \
# 0     1                                創刊辭
# 1     2                             世界를 알라
# 2     3                   時急히 解決할 朝鮮의 二大問題
# 3     4        世界 三大 問題의 波及과 朝鮮人의 覺悟如何, 社說
# 4     5                      最近 朝鮮社會運動의 二三
# 5     6  急激히 向上되는 朝鮮靑年의 思想界, 可賀할 朝鮮靑年의 知識熱
# 6     7                     吾人의 新紀元을 宣言하노라
# 7     8                           新時代와 新人物
# 8     9                          家族制度의 側面觀
# 9    10                         朝鮮女子의 今後行路
#
#                                              content
# 0  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1  世界를 알라\n一\n사람은 天使도 안이며 野獸도 안이오 오즉 사람일 뿐이로다. 이만...
# 2  時急히 解決할 朝鮮의 二大問題\n朴達成\n남은 汽車를 타고 千里에 달아나는데 우리는...
# 3  世界 三大 問題의 波及과 朝鮮人의 覺悟如何, 社說\n1. 三大 問題는 그를 吸收하고...
# 4  最近 朝鮮社會運動의 二三\n李敦化\n朝鮮敎育會, 朝鮮學生大會, 朝鮮勞働共濟會의 趣旨...
# 5  急激히 向上되는 朝鮮靑年의 思想界, 可賀할 朝鮮靑年의 知識熱\n朴達成\n無私한 태양...
# 6  吾人의 新紀元을 宣言하노라\n吾人은 均히 自國 歷史의 長遠을 자랑하고 自家譜乘의 久...
# 7  新時代와 新人物\n一. 改造라 함은 人類의 靈力이 自然의 上에 作用함을 이름이라\n...
# 8  家族制度의 側面觀\n滄海居士\n一. 家族制度의 變遷\n家族制度에도 美點이 업는 바 ...
# 9  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...

# %% [markdown]
# # 기사를 문장별로 분리

# %%
import re

# 기사를 문장별로 분리하는 사용자 함수
separators = ['\n', '\.', '!', '\?'] # 엔터 및 문장 종결 부호 (정규 표현식에서 사용하기 위해 escape 처리)

# separators를 하나의 정규 표현식 패턴으로 합칩니다.
pattern = '|'.join(separators)

# DataFrame의 'content' 열에 대해 패턴으로 분리를 수행하는 함수
df1 = df1.copy()
df1.loc[:, 'splited_sent'] = df1['content'].apply(lambda x: re.split(pattern, x))

# 결과 확인을 위해 처음 몇 줄을 출력할 수 있습니다.
df1.head()
# Out:
#    r_id                        title  \
# 0     1                          創刊辭
# 1     2                       世界를 알라
# 2     3             時急히 解決할 朝鮮의 二大問題
# 3     4  世界 三大 問題의 波及과 朝鮮人의 覺悟如何, 社說
# 4     5                最近 朝鮮社會運動의 二三
#
#                                              content  \
# 0  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1  世界를 알라\n一\n사람은 天使도 안이며 野獸도 안이오 오즉 사람일 뿐이로다. 이만...
# 2  時急히 解決할 朝鮮의 二大問題\n朴達成\n남은 汽車를 타고 千里에 달아나는데 우리는...
# 3  世界 三大 問題의 波及과 朝鮮人의 覺悟如何, 社說\n1. 三大 問題는 그를 吸收하고...
# 4  最近 朝鮮社會運動의 二三\n李敦化\n朝鮮敎育會, 朝鮮學生大會, 朝鮮勞働共濟會의 趣旨...
#
#                                         splited_sent
# 0  [創刊辭, 소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를...
# 1  [世界를 알라, 一, 사람은 天使도 안이며 野獸도 안이오 오즉 사람일 뿐이로다,  ...
# 2  [時急히 解決할 朝鮮의 二大問題, 朴達成, 남은 汽車를 타고 千里에 달아나는데 우리...
# 3  [世界 三大 問題의 波及과 朝鮮人의 覺悟如何, 社說, 1,  三大 問題는 그를 吸收...
# 4  [最近 朝鮮社會運動의 二三, 李敦化, 朝鮮敎育會, 朝鮮學生大會, 朝鮮勞働共濟會의 趣...

# %%
# 각 문장을 df의 행이 되도록 변환

sents_df = df1.explode('splited_sent')
sents_df = sents_df.reset_index(drop=True) # 인덱스를 재부여
sents_df
# Out:
#       r_id       title                                            content  \
# 0        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 2        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 3        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 4        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# ...    ...         ...                                                ...
# 1317    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1318    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1319    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1320    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1321    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
#
#                                            splited_sent
# 0                                                   創刊辭
# 1        소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 始作하도다
# 2                 强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다
# 3                           東西南北, 四海八方이 다같이 소리中에 묻혀 있도다
# 4         霹靂이냐 地震이냐 神籟이냐 魔哭이냐 우리는 아즉이 소리의 正邪를 判斷할 수 없도다
# ...                                                 ...
# 1317                                       그러나 저는 모르나이다
# 1318                다못 이 글을 올리는 이때에 느끼는 것을 그대로 적엇슬 뿐이외다
# 1319   틈을 어더 이에 對한 제의 所見을 具體的으로 말삼할 것을 豫期하오며 爲先 누의님의...
# 1320
# 1321                                       (이만) ＜29-33＞
#
# [1322 rows x 4 columns]

# %% [markdown]
# # 형태소 분석
# - 제목: 형태소 분석기 적용
# - kiwi 형태소 분석기로 텍스트 데이터 분석

# %% [markdown]
# ## kiwi 설치

# %%
# kiwi 설치
# !pip install -U kiwipiepy
# Out:
# Requirement already satisfied: kiwipiepy in c:\users\creta\anaconda3\lib\site-packages (0.17.1)
# Requirement already satisfied: kiwipiepy-model<0.18,>=0.17 in c:\users\creta\anaconda3\lib\site-packages (from kiwipiepy) (0.17.0)
# Requirement already satisfied: numpy in c:\users\creta\anaconda3\lib\site-packages (from kiwipiepy) (1.24.3)
# Requirement already satisfied: tqdm in c:\users\creta\anaconda3\lib\site-packages (from kiwipiepy) (4.65.0)
# Requirement already satisfied: colorama in c:\users\creta\anaconda3\lib\site-packages (from tqdm->kiwipiepy) (0.4.6)

# %% [markdown]
# ## 형태소 분석 함수 작성

# %%
from kiwipiepy import Kiwi

# Kiwi 객체 생성
kiwi = Kiwi()

# 텍스트 분석
text = "소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 始作하도다"
results = kiwi.analyze(text)

results
# Out:
# [([Token(form='소리', tag='NNG', start=0, len=2),
#    Token(form='-', tag='SO', start=2, len=1),
#    Token(form='있', tag='VV', start=3, len=1),
#    Token(form='어', tag='EC', start=4, len=1),
#    Token(form='넓히', tag='VV', start=6, len=2),
#    Token(form='世界', tag='SH', start=9, len=2),
#    Token(form='에', tag='JKB', start=11, len=1),
#    Token(form='傳', tag='SH', start=13, len=1),
#    Token(form='하', tag='VV', start=14, len=1),
#    Token(form='니', tag='EC', start=15, len=1),
#    Token(form='오', tag='VX', start=17, len=1),
#    Token(form='ᆫ', tag='ETM', start=17, len=1),
#    Token(form='世界', tag='SH', start=19, len=2),
#    Token(form='모든', tag='MAG', start=22, len=2),
#    Token(form='人類', tag='SH', start=25, len=2),
#    Token(form='-', tag='SO', start=27, len=1),
#    Token(form='이', tag='NNG', start=28, len=1),
#    Token(form='에', tag='JKB', start=29, len=1),
#    Token(form='應', tag='SH', start=31, len=1),
#    Token(form='하', tag='XSV', start=32, len=1),
#    Token(form='야', tag='EC', start=33, len=1),
#    Token(form='부르짖', tag='VV', start=35, len=3),
#    Token(form='기', tag='ETN', start=38, len=1),
#    Token(form='를', tag='JKO', start=39, len=1),
#    Token(form='始作', tag='SH', start=41, len=2),
#    Token(form='하', tag='XSV', start=43, len=1),
#    Token(form='도다', tag='EF', start=44, len=2)],
#   -202.34619140625)]

# %%
# 영어, 숫자, 특정 부호 등 제외하기
def filter_elements(lst):
    # 영어, 숫자 및 '<' 문자만을 허용하는 정규식 패턴
    pattern = re.compile(r'^[a-zA-Z0-9<＞「」]+$')

    # 해당 패턴과 일치하지 않는 문자열만을 반환하는 필터링 함수
    return list(filter(lambda x: not pattern.match(x), lst))

# 형태소 분석 결과를 단순한 형태로 출력하는 사용자 함수
def simplify_kiwi(sent):
    morphed_list = []
    results = kiwi.analyze(sent)
    for result in results:
        for token in result[0]:  # result는 (token_list, int) 형태의 튜플입니다.
            morphed = (token.form + "/" + token.tag)  # 각 토큰의 형태소와 품사 태그 출력
            morphed_list.append(morphed)
    return morphed_list

# 본격 형태소 분석
import string
def do_morph(sent):
    # 토큰나이징 결과 확인 (subword + 한국어 형태소)
    vocab_list = simplify_kiwi(sent)
    result01 = filter_elements(vocab_list) # 영어, 숫자, 특정부호 제외 (사용자 함수)
    return result01

# %% [markdown]
# ## 형태소 분석 및 정리 정돈

# %%
print(sents_df.shape)
sents_df.head(5)
# Out:
# (1322, 4)
#    r_id title                                            content  \
# 0     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 2     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 3     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 4     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
#
#                                      splited_sent
# 0                                             創刊辭
# 1  소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 始作하도다
# 2           强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다
# 3                     東西南北, 四海八方이 다같이 소리中에 묻혀 있도다
# 4   霹靂이냐 地震이냐 神籟이냐 魔哭이냐 우리는 아즉이 소리의 正邪를 判斷할 수 없도다

# %%
# 'content' 열에 kiwi 형태소 분석기 적용
sents_df = sents_df.copy()
sents_df['tokens'] = sents_df['splited_sent'].apply(do_morph)
sents_df
# Out:
#       r_id       title                                            content  \
# 0        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 2        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 3        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 4        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# ...    ...         ...                                                ...
# 1317    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1318    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1319    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1320    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1321    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
#
#                                            splited_sent  \
# 0                                                   創刊辭
# 1        소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 始作하도다
# 2                 强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다
# 3                           東西南北, 四海八方이 다같이 소리中에 묻혀 있도다
# 4         霹靂이냐 地震이냐 神籟이냐 魔哭이냐 우리는 아즉이 소리의 正邪를 判斷할 수 없도다
# ...                                                 ...
# 1317                                       그러나 저는 모르나이다
# 1318                다못 이 글을 올리는 이때에 느끼는 것을 그대로 적엇슬 뿐이외다
# 1319   틈을 어더 이에 對한 제의 所見을 具體的으로 말삼할 것을 豫期하오며 爲先 누의님의...
# 1320
# 1321                                       (이만) ＜29-33＞
#
#                                                  tokens
# 0                                              [創刊辭/SH]
# 1     [소리/NNG, -/SO, 있/VV, 어/EC, 넓히/VV, 世界/SH, 에/JKB...
# 2     [强者/SH, 도/JX, 부르짖/VV, 고/EC, 弱者/SH, 도/JX, 부르짖/V...
# 3     [東西南北/SH, ,/SP, 四海八方/SH, 이/JKS, 다/MAG, 같이/MAG,...
# 4     [霹靂/SH, 이냐/NNG, 地震/SH, 이/VCP, 냐/EC, 神籟/SH, 이/V...
# ...                                                 ...
# 1317    [그러나/MAJ, 저/NP, 는/JX, 모르/VV, 나/EC, 이/VCP, 다/EF]
# 1318  [다/MAG, 못/MAG, 이/MM, 글/NNG, 을/JKO, 올리/VV, 는/ET...
# 1319  [틈/NNG, 을/JKO, 어/IC, 더/MAG, 이/NP, 에/JKB, 對/SH,...
# 1320                                                 []
# 1321  [(/SSO, 이만/MAG, )/SSC, ＜/SSO, 29-33/W_SERIAL, ...
#
# [1322 rows x 5 columns]

# %%
# 'tokens' 열에서 리스트 요소가 하나도 없는 행 제거
sents_df1 = sents_df[sents_df['tokens'].str.len() > 0]

sents_df1 = sents_df1.copy()
sents_df1['tokens'] = sents_df1['tokens'].apply(lambda x: ' '.join(x)) # 리스트를 문자열로

sents_df1.reset_index(drop=True, inplace=True) # 인덱스 초기화
sents_df1['sent_id'] = sents_df1.index + 1 # sent_id 재넘버링
sents_df1
# Out:
#       r_id       title                                            content  \
# 0        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 2        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 3        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 4        1         創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# ...    ...         ...                                                ...
# 1140    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1141    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1142    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1143    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1144    10  朝鮮女子의 今後行路  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
#
#                                            splited_sent  \
# 0                                                   創刊辭
# 1        소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 始作하도다
# 2                 强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다
# 3                           東西南北, 四海八方이 다같이 소리中에 묻혀 있도다
# 4         霹靂이냐 地震이냐 神籟이냐 魔哭이냐 우리는 아즉이 소리의 正邪를 判斷할 수 없도다
# ...                                                 ...
# 1140           그런 中에도 말이 아모 脈絡이 업고 成筭이 업는 말할 수 업는 粗笨이외다
# 1141                                       그러나 저는 모르나이다
# 1142                다못 이 글을 올리는 이때에 느끼는 것을 그대로 적엇슬 뿐이외다
# 1143   틈을 어더 이에 對한 제의 所見을 具體的으로 말삼할 것을 豫期하오며 爲先 누의님의...
# 1144                                       (이만) ＜29-33＞
#
#                                                  tokens  sent_id
# 0                                                創刊辭/SH        1
# 1     소리/NNG -/SO 있/VV 어/EC 넓히/VV 世界/SH 에/JKB 傳/SH 하...        2
# 2     强者/SH 도/JX 부르짖/VV 고/EC 弱者/SH 도/JX 부르짖/VV 으며/EC...        3
# 3     東西南北/SH ,/SP 四海八方/SH 이/JKS 다/MAG 같이/MAG 소리/NNG...        4
# 4     霹靂/SH 이냐/NNG 地震/SH 이/VCP 냐/EC 神籟/SH 이/VCP 냐/EC...        5
# ...                                                 ...      ...
# 1140  그런/MM 中/SH 에/JKB 도/JX 말/NNG 이/JKS 아모/NNG 脈絡/SH...     1141
# 1141            그러나/MAJ 저/NP 는/JX 모르/VV 나/EC 이/VCP 다/EF     1142
# 1142  다/MAG 못/MAG 이/MM 글/NNG 을/JKO 올리/VV 는/ETM 이때/NN...     1143
# 1143  틈/NNG 을/JKO 어/IC 더/MAG 이/NP 에/JKB 對/SH 하/XSV ᆫ...     1144
# 1144      (/SSO 이만/MAG )/SSC ＜/SSO 29-33/W_SERIAL ＞/SSC     1145
#
# [1145 rows x 6 columns]

# %%
sents_df1['morph'] = sents_df1['tokens'].apply(
    lambda x: [token.split('/')[0] for token in x.split() if token.split('/')[-1] in ['SH', 'NP', 'NNP', 'NNG']]
)

# 'morph' 열에서 리스트 요소가 하나도 없는 행 제거
sents_df2 = sents_df1[sents_df1['morph'].str.len() > 0]

# 리스트를 문자열로
sents_df2 = sents_df2.copy()
sents_df2['morph'] = sents_df2['morph'].apply(lambda x: ' '.join(x)) 
sents_df2.head(5)
# Out:
#    r_id title                                            content  \
# 0     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 2     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 3     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 4     1   創刊辭  創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
#
#                                      splited_sent  \
# 0                                             創刊辭
# 1  소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 始作하도다
# 2           强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다
# 3                     東西南北, 四海八方이 다같이 소리中에 묻혀 있도다
# 4   霹靂이냐 地震이냐 神籟이냐 魔哭이냐 우리는 아즉이 소리의 正邪를 判斷할 수 없도다
#
#                                               tokens  sent_id  \
# 0                                             創刊辭/SH        1
# 1  소리/NNG -/SO 있/VV 어/EC 넓히/VV 世界/SH 에/JKB 傳/SH 하...        2
# 2  强者/SH 도/JX 부르짖/VV 고/EC 弱者/SH 도/JX 부르짖/VV 으며/EC...        3
# 3  東西南北/SH ,/SP 四海八方/SH 이/JKS 다/MAG 같이/MAG 소리/NNG...        4
# 4  霹靂/SH 이냐/NNG 地震/SH 이/VCP 냐/EC 神籟/SH 이/VCP 냐/EC...        5
#
#                         morph
# 0                         創刊辭
# 1        소리 世界 傳 世界 人類 이 應 始作
# 2                 强者 弱者 優者 劣者
# 3              東西南北 四海八方 소리 中
# 4  霹靂 이냐 地震 神籟 魔哭 우리 소리 正邪 判斷

# %%
sents = sents_df2[['sent_id', 'morph', 'splited_sent', 'r_id', 'title', 'content']]
sents = sents.reset_index(drop = True)
sents['sent_id'] = sents.index + 1
sents
# Out:
#       sent_id                                    morph  \
# 0           1                                      創刊辭
# 1           2                     소리 世界 傳 世界 人類 이 應 始作
# 2           3                              强者 弱者 優者 劣者
# 3           4                           東西南北 四海八方 소리 中
# 4           5               霹靂 이냐 地震 神籟 魔哭 우리 소리 正邪 判斷
# ...       ...                                      ...
# 1097     1098                                   누 님 片紙
# 1098     1099                     中 말 아모 脈絡 成筭 말 粗笨 이외
# 1099     1100                                        저
# 1100     1101                                     글 이때
# 1101     1102  틈 이 對 所見 具體的 말 삼 豫期 爲先 누의 斯界 對 獨特 意見 敢仰
#
#                                            splited_sent  r_id       title  \
# 0                                                   創刊辭     1         創刊辭
# 1        소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 始作하도다     1         創刊辭
# 2                 强者도 부르짖고 弱者도 부르짖으며 優者도 부르짖고 劣者도 부르짖도다     1         創刊辭
# 3                           東西南北, 四海八方이 다같이 소리中에 묻혀 있도다     1         創刊辭
# 4         霹靂이냐 地震이냐 神籟이냐 魔哭이냐 우리는 아즉이 소리의 正邪를 判斷할 수 없도다     1         創刊辭
# ...                                                 ...   ...         ...
# 1097                                  누의님 片紙가 넘우 길어젓슴니다    10  朝鮮女子의 今後行路
# 1098           그런 中에도 말이 아모 脈絡이 업고 成筭이 업는 말할 수 업는 粗笨이외다    10  朝鮮女子의 今後行路
# 1099                                       그러나 저는 모르나이다    10  朝鮮女子의 今後行路
# 1100                다못 이 글을 올리는 이때에 느끼는 것을 그대로 적엇슬 뿐이외다    10  朝鮮女子의 今後行路
# 1101   틈을 어더 이에 對한 제의 所見을 具體的으로 말삼할 것을 豫期하오며 爲先 누의님의...    10  朝鮮女子의 今後行路
#
#                                                 content
# 0     創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 1     創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 2     創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 3     創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# 4     創刊辭\n소리-있어 넓히 世界에 傳하니 온 世界 모든 人類-이에 應하야 부르짖기를 ...
# ...                                                 ...
# 1097  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1098  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1099  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1100  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
# 1101  朝鮮女子의 今後行路\n妙香山人\n누의님 悾惚한 이 歲月이 일만흔 우리에게 더욱 悾惚...
#
# [1102 rows x 6 columns]

# %% [markdown]
# # The End of Notebook
